# %% [markdown]
# Go to http://classic.fec.gov/disclosurep/PDownload.do and make sure you have ALL.zip downloaded

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import datetime as dt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('2016-donations.csv', index_col=False)
# Out:
# /Users/justinmi/anaconda3/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2871: DtypeWarning: Columns (6,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#            cmte_id    cand_id         cand_nm                 contbr_nm  \
# 0        C00458844  P60006723    Rubio, Marco             BLUM, MAUREEN
# 1        C00458844  P60006723    Rubio, Marco       DODSON, MARK B. MR.
# 2        C00458844  P60006723    Rubio, Marco         CHILDERS, WILLIAM
# 3        C00458844  P60006723    Rubio, Marco          RUCINSKI, ROBERT
# 4        C00458844  P60006723    Rubio, Marco          RUCINSKI, ROBERT
# 5        C00458844  P60006723    Rubio, Marco          MARQUEZ, PANFILO
# 6        C00458844  P60006723    Rubio, Marco          DOHERTY, THERESA
# 7        C00458844  P60006723    Rubio, Marco         CHILDERS, WILLIAM
# 8        C00458844  P60006723    Rubio, Marco            RECKER, ANGELA
# 9        C00458844  P60006723    Rubio, Marco        HEFFERNAN, MICHAEL
# 10       C00458844  P60006723    Rubio, Marco  CALLESEN JR., RICHARD O.
# 11       C00458844  P60006723    Rubio, Marco  CALLESEN JR., RICHARD O.
# 12       C00458844  P60006723    Rubio, Marco                 KIM, TONY
# 13       C00458844  P60006723    Rubio, Marco        HEFFERNAN, MICHAEL
# 14       C00458844  P60006723    Rubio, Marco        HEFFERNAN, MICHAEL
# 15       C00458844  P60006723    Rubio, Marco            RECKER, ANGELA
# 16       C00458844  P60006723    Rubio, Marco       RECKER, CHRISTOPHER
# 17       C00458844  P60006723    Rubio, Marco       RECKER, CHRISTOPHER
# 18       C00458844  P60006723    Rubio, Marco        HEFFERNAN, MICHAEL
# 19       C00458844  P60006723    Rubio, Marco             KIBBLE, KUMAR
# 20       C00458844  P60006723    Rubio, Marco              OLSEN, GLENN
# 21       C00458844  P60006723    Rubio, Marco              OLSEN, GLENN
# 22       C00458844  P60006723    Rubio, Marco       JANELLI, REBECCA T.
# 23       C00458844  P60006723    Rubio, Marco       ACCINELLI, THEODORA
# 24       C00458844  P60006723    Rubio, Marco       ACCINELLI, THEODORA
# 25       C00458844  P60006723    Rubio, Marco              CREWS, PETER
# 26       C00458844  P60006723    Rubio, Marco              CREWS, PETER
# 27       C00458844  P60006723    Rubio, Marco            BANNAN, STUART
# 28       C00458844  P60006723    Rubio, Marco           DONAHUE, THOMAS
# 29       C00458844  P60006723    Rubio, Marco         BELIN, LYNDEN MR.
# ...            ...        ...             ...                       ...
# 7440222  C00623884  P60022654  McMullin, Evan            BOTANA, JOSEPH
# 7440223  C00623884  P60022654  McMullin, Evan            BOTANA, JOSEPH
# 7440224  C00623884  P60022654  McMullin, Evan            MUNSON, NATHAN
# 7440225  C00623884  P60022654  McMullin, Evan           DOHS, CATHERINE
# 7440226  C00623884  P60022654  McMullin, Evan        BALINSKI, JONATHAN
# 7440227  C00623884  P60022654  McMullin, Evan            DAVIS, DOUGLAS
# 7440228  C00623884  P60022654  McMullin, Evan            DAVIS, DOUGLAS
# 7440229  C00623884  P60022654  McMullin, Evan            HILTON, THOMAS
# 7440230  C00623884  P60022654  McMullin, Evan            BOTANA, JOSEPH
# 7440231  C00623884  P60022654  McMullin, Evan             VENTO, RACHEL
# 7440232  C00623884  P60022654  McMullin, Evan             RANKER, ELLEN
# 7440233  C00623884  P60022654  McMullin, Evan         COGLIANESE, MARCY
# 7440234  C00623884  P60022654  McMullin, Evan              MAUS, DANIEL
# 7440235  C00623884  P60022654  McMullin, Evan        WILKINSON, STEPHEN
# 7440236  C00623884  P60022654  McMullin, Evan           MCDONALD, KAREN
# 7440237  C00623884  P60022654  McMullin, Evan          HIEMENZ, CAROLYN
# 7440238  C00623884  P60022654  McMullin, Evan          DEPAULO, WILLIAM
# 7440239  C00623884  P60022654  McMullin, Evan            HINMAN, PAUL V
# 7440240  C00623884  P60022654  McMullin, Evan           MARNER, JUANITA
# 7440241  C00623884  P60022654  McMullin, Evan          DEPAULO, WILLIAM
# 7440242  C00623884  P60022654  McMullin, Evan             KEEFER, KAREN
# 7440243  C00623884  P60022654  McMullin, Evan              GREER, DEBRA
# 7440244  C00623884  P60022654  McMullin, Evan              GREER, DEBRA
# 7440245  C00623884  P60022654  McMullin, Evan              GREER, DEBRA
# 7440246  C00623884  P60022654  McMullin, Evan              ASTLE, BECKY
# 7440247  C00623884  P60022654  McMullin, Evan              GREER, DEBRA
# 7440248  C00623884  P60022654  McMullin, Evan              ASTLE, BECKY
# 7440249  C00623884  P60022654  McMullin, Evan              GREER, DEBRA
# 7440250  C00623884  P60022654  McMullin, Evan            MCCORT, HANNAH
# 7440251  C00623884  P60022654  McMullin, Evan             KERTESZ, JOHN
#
#          contbr_city contbr_st contbr_zip  \
# 0         WASHINGTON        20         DC
# 1            ATLANTA        30         GA
# 2                DPO        AE  098309998
# 3                APO        AE  090960009
# 4                APO        AE  090960009
# 5                DPO        AE  097770241
# 6                APO        AE  097520002
# 7                DPO        AE  098309998
# 8                APO        AE      00138
# 9                APO        AE      09096
# 10               FPO        AE  096230023
# 11               FPO        AE  096230023
# 12               APO        AE  091800022
# 13               APO        AE      09096
# 14               APO        AE      09096
# 15               APO        AE  090120060
# 16               APO        AE  090120096
# 17               APO        AE  090120096
# 18               APO        AE  090960009
# 19               DPO        AE  092131903
# 20          BIG LAKE        AK  996521432
# 21          BIG LAKE        AK  996521432
# 22         ANCHORAGE        AK  995076742
# 23         ANCHORAGE        AK  995014345
# 24         ANCHORAGE        AK  995014345
# 25         ANCHORAGE        AK  995022839
# 26         ANCHORAGE        AK  995022839
# 27            PALMER        AK  996459164
# 28       EAGLE RIVER        AK  995779277
# 29         ANCHORAGE        AK  995113045
# ...              ...       ...        ...
# 7440222         KIEL        WI      53042
# 7440223         KIEL        WI      53042
# 7440224     APPLETON        WI      54911
# 7440225       OREGON        WI      53575
# 7440226       VERONA        WI      53593
# 7440227      MADISON        WI      53717
# 7440228      MADISON        WI      53717
# 7440229   EAU CLAIRE        WI      54701
# 7440230         KIEL        WI      53042
# 7440231    MUKWONAGO        WI      53149
# 7440232   BURLINGTON        WI      53105
# 7440233      OSHKOSH        WI      54992
# 7440234      FONTANA        WI      53125
# 7440235    MILWAUKEE        WI      53228
# 7440236   OCONOMOWOC        WI      53066
# 7440237   GERMANTOWN        WI      53022
# 7440238    LEWISBURG        WV      24901
# 7440239   CHARLESTON        WV      25314
# 7440240       RANSON        WV      25438
# 7440241    LEWISBURG        WV      24901
# 7440242        GIVEN        WV      25245
# 7440243     EVANSTON        WY      82930
# 7440244     EVANSTON        WY      82930
# 7440245     EVANSTON        WY      82930
# 7440246       GROVER        WY      83122
# 7440247     EVANSTON        WY      82930
# 7440248       GROVER        WY      83122
# 7440249     EVANSTON        WY      82930
# 7440250      LARAMIE        WY      82072
# 7440251     GILLETTE        WY      82718
#
#                                 contbr_employer  \
# 0         STRATEGIC COALITIONS & INITIATIVES LL
# 1                     MORTGAGE CAPITAL ADVISORS
# 2                                      DIPLOMAT
# 3                                       US ARMY
# 4                                       US ARMY
# 5                           DEPARTMENT OF STATE
# 6                                      DODEA/DS
# 7                                      DIPLOMAT
# 8                                    GOVERNMENT
# 9                                       RETIRED
# 10                                      RETIRED
# 11                                      RETIRED
# 12                                         USAF
# 13                                      RETIRED
# 14                                      RETIRED
# 15                                   GOVERNMENT
# 16                                   GOVERNMENT
# 17                                   GOVERNMENT
# 18       INFORMATION REQUESTED PER BEST EFFORTS
# 19         U.S. DEPARTMENT OF HOMELAND SECURITY
# 20                                      RETIRED
# 21                                      RETIRED
# 22                                      RETIRED
# 23                                SELF-EMPLOYED
# 24                                SELF-EMPLOYED
# 25                                        AECOM
# 26                                        AECOM
# 27                                         ACLT
# 28                  ANCHORAGE POLICE DEPARTMENT
# 29       INFORMATION REQUESTED PER BEST EFFORTS
# ...                                         ...
# 7440222                           SELF-EMPLOYED
# 7440223                           SELF-EMPLOYED
# 7440224        RADIOLOGY ASSOCIATES OF APPLETON
# 7440225                                 RETIRED
# 7440226                            EPIC SYSTEMS
# 7440227                    MADISON RADIOLOGISTS
# 7440228                    MADISON RADIOLOGISTS
# 7440229                 UNIVERSITY OF WISCONSIN
# 7440230                           SELF-EMPLOYED
# 7440231                                     NaN
# 7440232                                 RETIRED
# 7440233                                 RETIRED
# 7440234                            EDWARD JONES
# 7440235                                   MCWAH
# 7440236                                    YMCA
# 7440237                           SELF-EMPLOYED
# 7440238                           SELF EMPLOYED
# 7440239                                 RETIRED
# 7440240                                     NIH
# 7440241                           SELF EMPLOYED
# 7440242                     BOOZ ALLEN HAMILTON
# 7440243                           SELF-EMPLOYED
# 7440244                           SELF-EMPLOYED
# 7440245                           SELF-EMPLOYED
# 7440246           LINCOLN COUNTY LIBRARY SYSTEM
# 7440247                           SELF-EMPLOYED
# 7440248           LINCOLN COUNTY LIBRARY SYSTEM
# 7440249                           SELF-EMPLOYED
# 7440250                                    SELF
# 7440251                          TATA CHEMICALS
#
#                               contbr_occupation  contb_receipt_amt  \
# 0                             OUTREACH DIRECTOR             175.00
# 1                      PRIVATE MORTGAGE BANKING              25.00
# 2                                 US GOVERNMENT             100.00
# 3                                     PHYSICIAN             200.00
# 4                                     PHYSICIAN             100.00
# 5                       FOREIGN SERVICE OFFICER             100.00
# 6                                       TEACHER             500.00
# 7                                 US GOVERNMENT             100.00
# 8                                      ATTORNEY             388.25
# 9                                       RETIRED             225.00
# 10                                      RETIRED              50.00
# 11                                      RETIRED              50.00
# 12                                     MILITARY             250.00
# 13                                      RETIRED             100.00
# 14                                      RETIRED             220.50
# 15                                     ATTORNEY             500.00
# 16                                        PILOT             500.00
# 17                                        PILOT             500.00
# 18       INFORMATION REQUESTED PER BEST EFFORTS             210.00
# 19                              LAW ENFORCEMENT             500.00
# 20                                      RETIRED             100.00
# 21                                      RETIRED             110.00
# 22                                      RETIRED             100.00
# 23                                     ATTORNEY              50.00
# 24                                     ATTORNEY             200.00
# 25                                     ENGINEER             100.00
# 26                                     ENGINEER             100.00
# 27                 COMMUNITY BUSINESS DEVELOPER             382.00
# 28                               POLICE OFFICER             250.00
# 29       INFORMATION REQUESTED PER BEST EFFORTS              50.00
# ...                                         ...                ...
# 7440222                     CONSULTANT-EDUCATOR              25.00
# 7440223                     CONSULTANT-EDUCATOR              25.00
# 7440224                               PHYSICIAN              50.00
# 7440225                                 RETIRED              10.00
# 7440226                      SOFTWARE DEVELOPER             250.00
# 7440227                               PHYSICIAN             750.00
# 7440228                               PHYSICIAN             300.00
# 7440229                               PROFESSOR             100.00
# 7440230                     CONSULTANT-EDUCATOR              25.00
# 7440231                        GRAPHIC DESIGNER             100.00
# 7440232                                 RETIRED              50.00
# 7440233                                 RETIRED              50.00
# 7440234                       FINANCIAL ADVISOR             200.00
# 7440235                      RESIDENT PHYSICIAN             100.00
# 7440236                           DANCE TEACHER              25.00
# 7440237                        GRAPHIC DESIGNER             100.00
# 7440238                                  LAWYER             100.00
# 7440239                                 RETIRED             100.00
# 7440240                          POLICY ANALYST             250.00
# 7440241                                  LAWYER             100.00
# 7440242                              CONSULTANT             100.00
# 7440243                   MEDICAL TRANSCRIPTION             100.00
# 7440244                   MEDICAL TRANSCRIPTION              32.50
# 7440245                   MEDICAL TRANSCRIPTION             100.00
# 7440246                               LIBRARIAN             150.00
# 7440247                   MEDICAL TRANSCRIPTION             250.00
# 7440248                               LIBRARIAN              50.00
# 7440249                   MEDICAL TRANSCRIPTION             200.00
# 7440250                        STAY AT HOME MOM             100.00
# 7440251                              HR MANAGER             250.00
#
#         contb_receipt_dt receipt_desc memo_cd        memo_text form_tp  \
# 0              15-MAR-16          NaN     NaN              NaN   SA17A
# 1              16-MAR-16          NaN     NaN  DEBT RETIREMENT   SA17A
# 2              20-FEB-16          NaN     NaN              NaN   SA17A
# 3              10-MAR-16          NaN     NaN              NaN   SA17A
# 4              08-MAR-16          NaN     NaN              NaN   SA17A
# 5              07-MAR-16          NaN     NaN              NaN   SA17A
# 6              26-JUN-15          NaN     NaN              NaN   SA17A
# 7              06-FEB-16          NaN     NaN              NaN   SA17A
# 8              18-MAR-16          NaN     NaN  DEBT RETIREMENT   SA17A
# 9              29-OCT-15          NaN     NaN              NaN   SA17A
# 10             14-JAN-16          NaN     NaN              NaN   SA17A
# 11             25-JAN-16          NaN     NaN              NaN   SA17A
# 12             29-JAN-16          NaN     NaN              NaN   SA17A
# 13             18-JAN-16          NaN     NaN              NaN   SA17A
# 14             15-JAN-16          NaN     NaN              NaN   SA17A
# 15             09-FEB-16          NaN     NaN              NaN   SA17A
# 16             09-FEB-16          NaN     NaN              NaN   SA17A
# 17             09-FEB-16          NaN     NaN              NaN   SA17A
# 18             27-JUN-15          NaN     NaN              NaN   SA17A
# 19             27-AUG-15          NaN     NaN              NaN   SA17A
# 20             16-FEB-16          NaN     NaN              NaN   SA17A
# 21             24-FEB-16          NaN     NaN              NaN   SA17A
# 22             16-FEB-16          NaN     NaN              NaN   SA17A
# 23             11-FEB-16          NaN     NaN              NaN   SA17A
# 24             02-FEB-16          NaN     NaN              NaN   SA17A
# 25             29-FEB-16          NaN     NaN              NaN   SA17A
# 26             03-FEB-16          NaN     NaN              NaN   SA17A
# 27             02-FEB-16          NaN     NaN              NaN   SA17A
# 28             26-FEB-16          NaN     NaN              NaN   SA17A
# 29             08-FEB-16          NaN     NaN              NaN   SA17A
# ...                  ...          ...     ...              ...     ...
# 7440222        21-OCT-16          NaN     NaN              NaN   SA17A
# 7440223        30-OCT-16          NaN     NaN              NaN   SA17A
# 7440224        20-OCT-16          NaN     NaN              NaN   SA17A
# 7440225        08-NOV-16          NaN     NaN              NaN   SA17A
# 7440226        03-NOV-16          NaN     NaN              NaN   SA17A
# 7440227        22-OCT-16          NaN     NaN              NaN   SA17A
# 7440228        21-OCT-16          NaN     NaN              NaN   SA17A
# 7440229        21-OCT-16          NaN     NaN              NaN   SA17A
# 7440230        05-NOV-16          NaN     NaN              NaN   SA17A
# 7440231        22-OCT-16          NaN     NaN              NaN   SA17A
# 7440232        04-NOV-16          NaN     NaN              NaN   SA17A
# 7440233        01-NOV-16          NaN     NaN              NaN   SA17A
# 7440234        27-OCT-16          NaN     NaN              NaN   SA17A
# 7440235        26-OCT-16          NaN     NaN              NaN   SA17A
# 7440236        04-NOV-16          NaN     NaN              NaN   SA17A
# 7440237        30-OCT-16          NaN     NaN              NaN   SA17A
# 7440238        03-NOV-16          NaN     NaN              NaN   SA17A
# 7440239        26-OCT-16          NaN     NaN              NaN   SA17A
# 7440240        03-NOV-16          NaN     NaN              NaN   SA17A
# 7440241        27-OCT-16          NaN     NaN              NaN   SA17A
# 7440242        06-OCT-16          NaN     NaN              NaN   SA17A
# 7440243        08-SEP-16          NaN     NaN              NaN   SA17A
# 7440244        25-SEP-16          NaN     NaN              NaN   SA17A
# 7440245        30-SEP-16          NaN     NaN              NaN   SA17A
# 7440246        08-OCT-16          NaN     NaN              NaN   SA17A
# 7440247        12-OCT-16          NaN     NaN              NaN   SA17A
# 7440248        15-SEP-16          NaN     NaN              NaN   SA17A
# 7440249        06-NOV-16          NaN     NaN              NaN   SA17A
# 7440250        04-NOV-16          NaN     NaN              NaN   SA17A
# 7440251        31-OCT-16          NaN     NaN              NaN   SA17A
#
#          file_num       tran_id election_tp
# 0         1082559  SA17.1152124       P2016
# 1         1082559  SA17.1153048       P2016
# 2         1056862  SA17.1020839       P2016
# 3         1082559  SA17.1078677       P2016
# 4         1082559  SA17.1074981       P2016
# 5         1082559  SA17.1074238       P2016
# 6         1029436   SA17.769700       P2016
# 7         1056862  SA17.1125521       P2016
# 8         1082559  SA17.1153167       P2016
# 9         1047126   SA17.863181       P2016
# 10        1051592   SA17.942388       P2016
# 11        1051592   SA17.989313       P2016
# 12        1051592   SA17.980184       P2016
# 13        1051592   SA17.944935       P2016
# 14        1051592   SA17.994421       P2016
# 15        1056862  SA17.1002064       P2016
# 16        1056862  SA17.1002077       P2016
# 17        1056862  SA17.1002084       P2016
# 18        1029436   SA17.796904       P2016
# 19        1031526   SA17.813360       P2016
# 20        1056862  SA17.1014613       P2016
# 21        1056862  SA17.1032864       P2016
# 22        1056862  SA17.1011767       P2016
# 23        1056862  SA17.1005844       P2016
# 24        1056862   SA17.971470       P2016
# 25        1056862  SA17.1079907       P2016
# 26        1056862  SA17.1079908       P2016
# 27        1056862  SA17.1091940       P2016
# 28        1056862  SA17.1042959       P2016
# 29        1056862   SA17.997405       P2016
# ...           ...           ...         ...
# 7440222   1132183   SA17A.60164         NaN
# 7440223   1132183   SA17A.60163         NaN
# 7440224   1132183   SA17A.57177         NaN
# 7440225   1132183   SA17A.69074         NaN
# 7440226   1132183   SA17A.53653         NaN
# 7440227   1132183   SA17A.53373         NaN
# 7440228   1132183   SA17A.53480         NaN
# 7440229   1132183   SA17A.53925         NaN
# 7440230   1132183   SA17A.60162         NaN
# 7440231   1132183   SA17A.54945         NaN
# 7440232   1132183   SA17A.57150         NaN
# 7440233   1132183   SA17A.57155         NaN
# 7440234   1132183   SA17A.53728         NaN
# 7440235   1132183   SA17A.55008         NaN
# 7440236   1132183   SA17A.58974         NaN
# 7440237   1132183   SA17A.54154         NaN
# 7440238   1132183   SA17A.54326         NaN
# 7440239   1132183   SA17A.54773         NaN
# 7440240   1132183   SA17A.53617         NaN
# 7440241   1132183   SA17A.54327         NaN
# 7440242   1125270   SA17A.27743       G2016
# 7440243   1125269   SA17A.22469       G2016
# 7440244   1125269   SA17A.26165       G2016
# 7440245   1125269   SA17A.22470       G2016
# 7440246   1125270   SA17A.27010       G2016
# 7440247   1125270   SA17A.26783       G2016
# 7440248   1125269   SA17A.22481       G2016
# 7440249   1132183   SA17A.53707         NaN
# 7440250   1132183   SA17A.54329         NaN
# 7440251   1132183   SA17A.76793         NaN
#
# [7440252 rows x 18 columns]

# %%
df.head()
# Out:
#      cmte_id    cand_id       cand_nm            contbr_nm contbr_city  \
# 0  C00458844  P60006723  Rubio, Marco        BLUM, MAUREEN  WASHINGTON
# 1  C00458844  P60006723  Rubio, Marco  DODSON, MARK B. MR.     ATLANTA
# 2  C00458844  P60006723  Rubio, Marco    CHILDERS, WILLIAM         DPO
# 3  C00458844  P60006723  Rubio, Marco     RUCINSKI, ROBERT         APO
# 4  C00458844  P60006723  Rubio, Marco     RUCINSKI, ROBERT         APO
#
#   contbr_st contbr_zip                        contbr_employer  \
# 0        20         DC  STRATEGIC COALITIONS & INITIATIVES LL
# 1        30         GA              MORTGAGE CAPITAL ADVISORS
# 2        AE  098309998                               DIPLOMAT
# 3        AE  090960009                                US ARMY
# 4        AE  090960009                                US ARMY
#
#           contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0         OUTREACH DIRECTOR              175.0        15-MAR-16          NaN
# 1  PRIVATE MORTGAGE BANKING               25.0        16-MAR-16          NaN
# 2             US GOVERNMENT              100.0        20-FEB-16          NaN
# 3                 PHYSICIAN              200.0        10-MAR-16          NaN
# 4                 PHYSICIAN              100.0        08-MAR-16          NaN
#
#   memo_cd        memo_text form_tp  file_num       tran_id election_tp
# 0     NaN              NaN   SA17A   1082559  SA17.1152124       P2016
# 1     NaN  DEBT RETIREMENT   SA17A   1082559  SA17.1153048       P2016
# 2     NaN              NaN   SA17A   1056862  SA17.1020839       P2016
# 3     NaN              NaN   SA17A   1082559  SA17.1078677       P2016
# 4     NaN              NaN   SA17A   1082559  SA17.1074981       P2016

# %%
df.shape # dimensions
# Out:
# (7440252, 18)

# %%
df.describe() # provides summary
# Out:
#        contb_receipt_amt      file_num
# count       7.440252e+06  7.440252e+06
# mean        1.261310e+02  1.101464e+06
# std         7.623128e+03  2.975025e+04
# min        -9.330800e+04  1.003942e+06
# 25%         1.500000e+01  1.077916e+06
# 50%         2.800000e+01  1.098663e+06
# 75%         9.435000e+01  1.133832e+06
# max         1.277771e+07  1.146285e+06

# %%
df.columns # shows cols
# Out:
# Index(['cmte_id', 'cand_id', 'cand_nm', 'contbr_nm', 'contbr_city',
#        'contbr_st', 'contbr_zip', 'contbr_employer', 'contbr_occupation',
#        'contb_receipt_amt', 'contb_receipt_dt', 'receipt_desc', 'memo_cd',
#        'memo_text', 'form_tp', 'file_num', 'tran_id', 'election_tp'],
#       dtype='object')

# %%
df.cand_id # use dot notation to access a col
df.cand_id.head()
# Out:
# 0    P60006723
# 1    P60006723
# 2    P60006723
# 3    P60006723
# 4    P60006723
# Name: cand_id, dtype: object

# %%
contributions = df[['cand_nm', 'contb_receipt_dt', 'contb_receipt_amt', 'contbr_nm', 'election_tp']] # get subset of matrix
contributions
# Out:
#                 cand_nm contb_receipt_dt  contb_receipt_amt  \
# 0          Rubio, Marco        15-MAR-16             175.00
# 1          Rubio, Marco        16-MAR-16              25.00
# 2          Rubio, Marco        20-FEB-16             100.00
# 3          Rubio, Marco        10-MAR-16             200.00
# 4          Rubio, Marco        08-MAR-16             100.00
# 5          Rubio, Marco        07-MAR-16             100.00
# 6          Rubio, Marco        26-JUN-15             500.00
# 7          Rubio, Marco        06-FEB-16             100.00
# 8          Rubio, Marco        18-MAR-16             388.25
# 9          Rubio, Marco        29-OCT-15             225.00
# 10         Rubio, Marco        14-JAN-16              50.00
# 11         Rubio, Marco        25-JAN-16              50.00
# 12         Rubio, Marco        29-JAN-16             250.00
# 13         Rubio, Marco        18-JAN-16             100.00
# 14         Rubio, Marco        15-JAN-16             220.50
# 15         Rubio, Marco        09-FEB-16             500.00
# 16         Rubio, Marco        09-FEB-16             500.00
# 17         Rubio, Marco        09-FEB-16             500.00
# 18         Rubio, Marco        27-JUN-15             210.00
# 19         Rubio, Marco        27-AUG-15             500.00
# 20         Rubio, Marco        16-FEB-16             100.00
# 21         Rubio, Marco        24-FEB-16             110.00
# 22         Rubio, Marco        16-FEB-16             100.00
# 23         Rubio, Marco        11-FEB-16              50.00
# 24         Rubio, Marco        02-FEB-16             200.00
# 25         Rubio, Marco        29-FEB-16             100.00
# 26         Rubio, Marco        03-FEB-16             100.00
# 27         Rubio, Marco        02-FEB-16             382.00
# 28         Rubio, Marco        26-FEB-16             250.00
# 29         Rubio, Marco        08-FEB-16              50.00
# ...                 ...              ...                ...
# 7440222  McMullin, Evan        21-OCT-16              25.00
# 7440223  McMullin, Evan        30-OCT-16              25.00
# 7440224  McMullin, Evan        20-OCT-16              50.00
# 7440225  McMullin, Evan        08-NOV-16              10.00
# 7440226  McMullin, Evan        03-NOV-16             250.00
# 7440227  McMullin, Evan        22-OCT-16             750.00
# 7440228  McMullin, Evan        21-OCT-16             300.00
# 7440229  McMullin, Evan        21-OCT-16             100.00
# 7440230  McMullin, Evan        05-NOV-16              25.00
# 7440231  McMullin, Evan        22-OCT-16             100.00
# 7440232  McMullin, Evan        04-NOV-16              50.00
# 7440233  McMullin, Evan        01-NOV-16              50.00
# 7440234  McMullin, Evan        27-OCT-16             200.00
# 7440235  McMullin, Evan        26-OCT-16             100.00
# 7440236  McMullin, Evan        04-NOV-16              25.00
# 7440237  McMullin, Evan        30-OCT-16             100.00
# 7440238  McMullin, Evan        03-NOV-16             100.00
# 7440239  McMullin, Evan        26-OCT-16             100.00
# 7440240  McMullin, Evan        03-NOV-16             250.00
# 7440241  McMullin, Evan        27-OCT-16             100.00
# 7440242  McMullin, Evan        06-OCT-16             100.00
# 7440243  McMullin, Evan        08-SEP-16             100.00
# 7440244  McMullin, Evan        25-SEP-16              32.50
# 7440245  McMullin, Evan        30-SEP-16             100.00
# 7440246  McMullin, Evan        08-OCT-16             150.00
# 7440247  McMullin, Evan        12-OCT-16             250.00
# 7440248  McMullin, Evan        15-SEP-16              50.00
# 7440249  McMullin, Evan        06-NOV-16             200.00
# 7440250  McMullin, Evan        04-NOV-16             100.00
# 7440251  McMullin, Evan        31-OCT-16             250.00
#
#                         contbr_nm election_tp
# 0                   BLUM, MAUREEN       P2016
# 1             DODSON, MARK B. MR.       P2016
# 2               CHILDERS, WILLIAM       P2016
# 3                RUCINSKI, ROBERT       P2016
# 4                RUCINSKI, ROBERT       P2016
# 5                MARQUEZ, PANFILO       P2016
# 6                DOHERTY, THERESA       P2016
# 7               CHILDERS, WILLIAM       P2016
# 8                  RECKER, ANGELA       P2016
# 9              HEFFERNAN, MICHAEL       P2016
# 10       CALLESEN JR., RICHARD O.       P2016
# 11       CALLESEN JR., RICHARD O.       P2016
# 12                      KIM, TONY       P2016
# 13             HEFFERNAN, MICHAEL       P2016
# 14             HEFFERNAN, MICHAEL       P2016
# 15                 RECKER, ANGELA       P2016
# 16            RECKER, CHRISTOPHER       P2016
# 17            RECKER, CHRISTOPHER       P2016
# 18             HEFFERNAN, MICHAEL       P2016
# 19                  KIBBLE, KUMAR       P2016
# 20                   OLSEN, GLENN       P2016
# 21                   OLSEN, GLENN       P2016
# 22            JANELLI, REBECCA T.       P2016
# 23            ACCINELLI, THEODORA       P2016
# 24            ACCINELLI, THEODORA       P2016
# 25                   CREWS, PETER       P2016
# 26                   CREWS, PETER       P2016
# 27                 BANNAN, STUART       P2016
# 28                DONAHUE, THOMAS       P2016
# 29              BELIN, LYNDEN MR.       P2016
# ...                           ...         ...
# 7440222            BOTANA, JOSEPH         NaN
# 7440223            BOTANA, JOSEPH         NaN
# 7440224            MUNSON, NATHAN         NaN
# 7440225           DOHS, CATHERINE         NaN
# 7440226        BALINSKI, JONATHAN         NaN
# 7440227            DAVIS, DOUGLAS         NaN
# 7440228            DAVIS, DOUGLAS         NaN
# 7440229            HILTON, THOMAS         NaN
# 7440230            BOTANA, JOSEPH         NaN
# 7440231             VENTO, RACHEL         NaN
# 7440232             RANKER, ELLEN         NaN
# 7440233         COGLIANESE, MARCY         NaN
# 7440234              MAUS, DANIEL         NaN
# 7440235        WILKINSON, STEPHEN         NaN
# 7440236           MCDONALD, KAREN         NaN
# 7440237          HIEMENZ, CAROLYN         NaN
# 7440238          DEPAULO, WILLIAM         NaN
# 7440239            HINMAN, PAUL V         NaN
# 7440240           MARNER, JUANITA         NaN
# 7440241          DEPAULO, WILLIAM         NaN
# 7440242             KEEFER, KAREN       G2016
# 7440243              GREER, DEBRA       G2016
# 7440244              GREER, DEBRA       G2016
# 7440245              GREER, DEBRA       G2016
# 7440246              ASTLE, BECKY       G2016
# 7440247              GREER, DEBRA       G2016
# 7440248              ASTLE, BECKY       G2016
# 7440249              GREER, DEBRA         NaN
# 7440250            MCCORT, HANNAH         NaN
# 7440251             KERTESZ, JOHN         NaN
#
# [7440252 rows x 5 columns]

# %%
clean_contributions = contributions.dropna() # eliminations NaN values

# %%
clean_contributions.shape
# Out:
# (7426230, 5)

# %%
contributions.shape[0] - clean_contributions.shape[0]
# Out:
# 14022

# %%
sum(pd.isnull(contributions['election_tp']))
# Out:
# 14022

# %%
clean_contributions.cand_nm.unique()
# Out:
# array(['Rubio, Marco', 'Santorum, Richard J.', 'Perry, James R. (Rick)',
#        'Carson, Benjamin S.', "Cruz, Rafael Edward 'Ted'", 'Paul, Rand',
#        'Clinton, Hillary Rodham', 'Sanders, Bernard', 'Fiorina, Carly',
#        'Huckabee, Mike', 'Pataki, George E.', "O'Malley, Martin Joseph",
#        'Graham, Lindsey O.', 'Bush, Jeb', 'Trump, Donald J.',
#        'Jindal, Bobby', 'Christie, Christopher J.', 'Walker, Scott',
#        'Stein, Jill', 'Webb, James Henry Jr.', 'Kasich, John R.',
#        'Gilmore, James S III', 'Lessig, Lawrence', 'Johnson, Gary',
#        'McMullin, Evan'], dtype=object)

# %%
trump_conts = clean_contributions[clean_contributions.cand_nm == 'Trump, Donald J.']

# %%
trump_conts.head()
# Out:
#                   cand_nm contb_receipt_dt  contb_receipt_amt  \
# 6588686  Trump, Donald J.        08-MAY-16             100.00
# 6588687  Trump, Donald J.        10-MAR-16              48.75
# 6588688  Trump, Donald J.        03-MAR-16             300.00
# 6588689  Trump, Donald J.        11-JUL-16              28.00
# 6588690  Trump, Donald J.        25-NOV-16             100.25
#
#                    contbr_nm election_tp
# 6588686  ECKERSALL, LAWRENCE       P2016
# 6588687     VANBEUGE, ROBERT       P2016
# 6588688     VANBEUGE, ROBERT       P2016
# 6588689     VANBEUGE, ROBERT       P2016
# 6588690      BLAKESLEE, TODD       G2016

# %%
trump_conts.describe()
# Out:
#        contb_receipt_amt
# count      771259.000000
# mean          155.834139
# std           372.764083
# min        -17705.000000
# 25%            28.000000
# 50%            60.000000
# 75%           160.000000
# max         86936.800000

# %%
bernie_conts = clean_contributions[clean_contributions.cand_nm == 'Sanders, Bernard']

# %%
bernie_conts.describe()
# Out:
#        contb_receipt_amt
# count       2.063094e+06
# mean        4.470614e+01
# std         1.420453e+02
# min        -9.330800e+04
# 25%         1.350000e+01
# 50%         2.700000e+01
# 75%         5.000000e+01
# max         1.000000e+04

# %%
hillary_conts = clean_contributions[clean_contributions.cand_nm == 'Clinton, Hillary Rodham']

# %%
hillary_conts.describe()
# Out:
#        contb_receipt_amt
# count       3.506056e+06
# mean        1.301792e+02
# std         4.777289e+03
# min        -2.000000e+04
# 25%         1.500000e+01
# 50%         2.500000e+01
# 75%         1.000000e+02
# max         4.904861e+06

# %%
hillary_conts_short = hillary_conts[abs(hillary_conts.contb_receipt_amt) > 100]

# %%
trump_conts_short = trump_conts[abs(trump_conts.contb_receipt_amt) > 100]
